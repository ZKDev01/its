# %%
import json 
from typing import List,Dict,Tuple
from langchain_ollama import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate

GEMMA = "gemma3:1b"
DEEPSEEK = "deepseek-r1:1.5b"

# %% [markdown]
# # LLM Question Generator
# Agente para generar preguntas y respuestas utilizando LLM. Este agente usa prompts estructurados para generar preguntas específicas. Además, crea respuestas para cada pregunta generada.

# %%
question_prompt = """ 
Genera {n_questions} preguntas sobre el tema "{topic}".
Las preguntas deben ser:
- Claras y específicas
- De diferentes niveles de dificultad (básico, intermedio, avanzado)
- Educativas y relevantes al tema

Formato de respuesta (JSON):
{{
  "preguntas": [
    "pregunta 1",
    "pregunta 2",
    ...
  ]
}}
"""
answer_prompt = """ 
Responde la siguiente pregunta sobre {topic} de manera clara, precisa y educativa.
La respuesta debe ser informativa pero concisa (2-4 párrafos máximo).

Pregunta: {question}

Respuesta:
"""

# %%
class QAGenerator:
  def __init__(self, model_name:str=GEMMA, temperature:float=0.7):
    """_summary_

    Args:
        model_name (str, optional): _description_. Defaults to GEMMA.
        temperature (float, optional): _description_. Defaults to 0.7.
    """
    self.llm = OllamaLLM(model=model_name, temperature=temperature)
    self.q_prompt = ChatPromptTemplate.from_template(question_prompt)
    self.a_prompt = ChatPromptTemplate.from_template(answer_prompt)
  
  def generate_questions(self, topic:str, n_questions:int, attempts:int=4) -> List[str]:
    "Genera preguntas para un tema específico" 
    try:
      chain = self.q_prompt | self.llm
      response = chain.invoke({
        "topic": topic,
        "n_questions": n_questions
      })
      
      # Intentar parsear JSON
      try:
        result = json.loads(response)
        questions = result.get("preguntas", [])
      except json.JSONDecodeError:
        # Si falla el JSON, extraer preguntas manualmente
        lines = response.split('\n')
        questions = []
        for line in lines:
          line = line.strip()
          if line and ('?' in line or line.startswith(('-', '*', '1.', '2.'))):
            # Limpiar formato de lista
            clean_question = line.replace('-', '').replace('*', '').strip()
            if clean_question.startswith(tuple('123456789')):
              clean_question = '. '.join(clean_question.split('. ')[1:])
            if clean_question:
              questions.append(clean_question)
            
      # Asegurar que tenemos el número correcto de preguntas
      if len(questions) > n_questions:
        questions = questions[:n_questions]
      elif len(questions) < n_questions:
        # Generar preguntas adicionales si es necesario
        additional_needed = n_questions - len(questions)
        for i in range(additional_needed):
          questions.append(f"Pregunta adicional sobre {topic} #{i+1}")
            
      return questions
            
    except Exception as e:
      if attempts != 0: self.generate_questions(topic, n_questions, attempts-1)
      print(f"Error generando preguntas para {topic}: {e}")
      # Preguntas de respaldo
      fallback_questions = [
        f"¿Qué es {topic}?",
        f"¿Cuáles son las características principales de {topic}?",
        f"¿Cómo se aplica {topic} en la práctica?",
        f"¿Cuáles son los conceptos fundamentales de {topic}?",
        f"¿Qué importancia tiene {topic} en la actualidad?"
      ]
      return fallback_questions[:n_questions]
  
  def generate_answer(self, question:str, topic:str) -> str:
    "Genera respuesta para una pregunta específica"
    try:
      chain = self.a_prompt | self.llm 
      response = chain.invoke({
        "question": question,
        "topic": topic
      })
      return response.strip()
    except Exception as e:
      return f"Error generando respuesta: {e}"
  
  def __call__(self, topics:Dict[str,int], verbose:bool=False) -> Dict[str, List[Tuple[str,str]]]:
    """Genera conjunto completo de preguntas y respuestas

    Args:
        topics (Dict[str,int]): diccionario con formato {"tema": cantidad_de_preguntas}

    Returns:
        Dict[str, List[Tuple[str,str]]]: diccionario con formato {"tema": [(pregunta, respuesta), ...]}
    """
    QA_set = {}
    for topic,n_questions in topics.items():
      # generar preguntas
      if verbose: print(f"=> Generando {n_questions} preguntas para: {topic}")
      questions = self.generate_questions(topic, n_questions)
      
      # generar respuestas
      qa_pairs = []
      for i, question in enumerate(questions, 1):
        if verbose: print(f"==> Generando respuesta {i}/{len(questions)}")
        answer = self.generate_answer(question, topic)
        qa_pairs.append((question, answer))
      
      QA_set[topic] = qa_pairs
    return QA_set

# %%
topics = {
  "Inteligencia Artificial": 3,
  "Matemática Discreta": 2,
}
generator = QAGenerator()
generator(topics=topics)
# Out:
# {'Inteligencia Artificial': [('"pregunta": "Considerando los desafíos éticos asociados al desarrollo y despliegue de la IA (como sesgo algorítmico y pérdida de empleos), ¿qué estrategias proponen los investigadores para mitigar estos riesgos y asegurar un uso responsable de la IA? Justifica tus respuestas con ejemplos de posibles enfoques.",',
#    'La ética de la Inteligencia Artificial (IA) se ha convertido en un campo de preocupación creciente, impulsado por los desafíos que plantea el desarrollo y la implementación de sistemas de IA. Uno de los principales desafíos es el **sesgo algorítmico**, que ocurre cuando los sistemas de IA aprenden de datos que reflejan sesgos existentes en la sociedad. Esto puede llevar a resultados injustos o discriminatorios en áreas como la contratación, la justicia penal, o incluso la concesión de préstamos. Por ejemplo, un sistema de reconocimiento facial entrenado principalmente con imágenes de personas de una raza específica podría tener dificultades para identificar correctamente a otras personas de otras etnias.  La mitigación de este riesgo requiere una mayor diversidad en los datos de entrenamiento y un desarrollo de algoritmos que sean inherentemente justos y transparentes.\n\nOtro desafío crucial es la **pérdida de empleos** debido a la automatización impulsada por la IA. Si bien la IA puede aumentar la productividad y la eficiencia, también amenaza con desplazar a trabajadores en diversas industrias. Para abordar esta amenaza, la investigación se centra en la **re-educación y la capacitación en nuevas habilidades**.  Además, es fundamental explorar la **economía de la renta básica universal (RBU)** como una posible solución para garantizar una red de seguridad para aquellos desplazados por la automatización.  La colaboración entre gobiernos, empresas y instituciones educativas es esencial para diseñar programas que preparen a la fuerza laboral para las nuevas oportunidades que surgirán con la IA.\n\nPara mitigar estos riesgos, los investigadores están explorando diversas estrategias.  Uno de los enfoques más prometedores es el **desarrollo de IA explicable (XAI)**, que busca hacer que los algoritmos de IA sean más transparentes y comprensibles para los humanos. Esto implica diseñar sistemas que puedan justificar sus decisiones y que permitan a los usuarios comprender cómo llegan a conclusiones.  Otro enfoque importante es la **ética de la IA**, que se centra en la consideración de los valores humanos y la implementación de principios que garanticen que la IA se utilice para el bien común.  Finalmente, la investigación en **IA robusta** busca desarrollar sistemas que sean menos susceptibles a ataques adversarios y que puedan funcionar de manera confiable incluso en condiciones inesperadas.\n\nEn resumen, la investigación en ética de la IA es crucial para garantizar que esta poderosa tecnología se desarrolle y se utilice de manera responsable, minimizando los riesgos potenciales y maximizando sus beneficios para la sociedad. La combinación de datos más diversos, algoritmos justos, políticas de re-educación y un enfoque en la ética de la IA es fundamental para navegar este futuro transformador.'),
#   ('Pregunta adicional sobre Inteligencia Artificial #1',
#    '¡Excelente! Aquí tienes una respuesta concisa sobre Inteligencia Artificial, enfocada en su importancia y potencial:\n\nLa Inteligencia Artificial (IA) está transformando el mundo, desde la medicina hasta la comunicación, y su impacto se expandirá aún más en los próximos años. La IA no es solo sobre robots; es un conjunto de técnicas que permiten a las máquinas aprender, razonar y resolver problemas como los humanos.  Su importancia radica en su capacidad para automatizar tareas, analizar grandes cantidades de datos y generar nuevas soluciones innovadoras.  Es fundamental comprender que la IA no reemplazará completamente el trabajo humano, sino que se complementará con él, liberando a las personas para enfocarse en tareas más creativas y estratégicas.  La investigación en IA está impulsando avances en áreas como el aprendizaje automático, el procesamiento del lenguaje natural y la visión por computadora, con el potencial de abordar algunos de los desafíos más urgentes de la humanidad.\n\n---\n\nWould you like me to elaborate on a specific aspect of AI, such as its applications or ethical considerations?'),
#   ('Pregunta adicional sobre Inteligencia Artificial #2',
#    '¡Excelente! Aquí tienes una respuesta concisa sobre Inteligencia Artificial, enfocada en su importancia y potencial:\n\n**La Inteligencia Artificial está transformando el mundo, desde la medicina hasta la comunicación, y su impacto se expandirá aún más con el avance tecnológico.  La IA no es solo un conjunto de algoritmos, sino una capacidad de crear sistemas que pueden aprender, razonar y resolver problemas complejos.  Su potencial para optimizar procesos, automatizar tareas y resolver desafíos globales es enorme, pero también es crucial abordar los desafíos éticos y sociales que conlleva su desarrollo y despliegue.  La clave está en utilizarla de manera responsable y con un enfoque centrado en el bienestar humano.**\n\n**En resumen, la IA es una herramienta poderosa que, con la guía de la ética y la responsabilidad, puede contribuir significativamente a mejorar la vida de las personas.**\n\n---\n\nWould you like me to elaborate on any of these points? For example, would you like me to discuss a specific application of AI or a key ethical consideration?')],
#  'Matemática Discreta': [('"text": "Qual é a diferença entre um número inteiro e um número decimal?"',
#    'La pregunta "¿Qual é a diferença entre um número inteiro y un número decimal?" es fundamental en matemáticas y tiene una respuesta clara y concisa.  En esencia, un número entero se basa en la cantidad de dígitos que tiene, mientras que un número decimal se basa en la cantidad de símbolos que utiliza para representar una fracción.  Vamos a profundizar en esta diferencia para comprender mejor por qué se utilizan cada uno.\n\nLos números enteros son los números que solo tienen dígitos, como 1, 2, 3, 4, 5, etc.  No tienen decimales.  Estos números son útiles para representar cantidades concretas, como el peso de un objeto o la distancia de un viaje.  La precisión de estos números es fundamental para muchas aplicaciones prácticas.\n\nEn contraste, los números decimales son aquellos que tienen un número de dígitos que incluye una parte decimal.  Por ejemplo, 3.14159, 10, 100, o 1000.  Estos números se utilizan para representar cantidades que tienen una componente de medida o comparación, como el precio de un producto, la temperatura o el tiempo.  La precisión de los decimales es importante en áreas como la ciencia, la ingeniería y las matemáticas, donde las fracciones y decimales son esenciales para realizar cálculos y análisis.\n\nLa principal diferencia radica en la forma en que se representan los valores. Los enteros se representan con dígitos individuales, mientras que los decimales se representan con un símbolo que indica una parte decimal.  La elección de usar un número entero o decimal depende del contexto y de la precisión requerida en la operación o el cálculo que se va a realizar.\n\nEn resumen, los números enteros son la base de la aritmética y la medición, mientras que los números decimales son esenciales para representar cantidades que tienen una componente de medida o comparación.  Ambos tipos de números tienen su propio valor y utilidad en diferentes contextos.'),
#   ('"text": "Descreva o papel da \'estabilidade numérica\' na análise de funções.  Como ela impacta a escolha de um método de cálculo?"',
#    'A estabilidade numérica, um conceito fundamental na análise de funções, desempenha um papel crucial na garantia da robustez, precisão e confiança nos resultados obtidos. Em sua essência, a estabilidade numérica visa minimizar a variação nos resultados de uma função, o que é vital para a precisão e a confiabilidade do cálculo.  Ela se manifesta através da garantia de que a sequência de resultados de uma função não se desvie significativamente de um valor conhecido, ou seja, um "ponto de referência".\n\nA estabilidade numérica é impulsionada por uma série de princípios matemáticos e estatísticos.  A principal técnica utilizada é o "teste de Ramsey", que avalia a variabilidade de uma função em relação a um valor de referência.  Um teste de Ramsey alto indica que a função apresenta uma grande variabilidade, o que pode levar a erros significativos.  A estabilidade numérica é, portanto, medida por um valor de Ramsey baixo, que indica uma boa qualidade de estimativa.\n\nO impacto da estabilidade numérica na escolha de um método de cálculo é significativo. Diferentes métodos de cálculo, como a diferença finita, a diferenciação numérica, ou a integração numérica, podem produzir resultados ligeiramente diferentes, mesmo com a mesma entrada de dados. A estabilidade numérica ajuda a selecionar um método que fornece estimativas mais precisas e confiáveis, minimizando a chance de erros significativos.  Alguns métodos são inerentemente mais robustos à variação do que outros, e a estabilidade numérica ajuda a identificar esses pontos fortes e fracos.\n\nEm resumo, a estabilidade numérica é um componente essencial da análise de funções, pois garante a qualidade e a confiabilidade dos resultados.  Ela impacta a escolha do método de cálculo, minimiza a variabilidade e, por fim, garante a precisão dos cálculos.  A implementação de técnicas de estabilidade numérica, como o teste de Ramsey, é uma prática padrão em diversas áreas da matemática e da ciência da computação, especialmente em áreas que envolvem a análise de funções, como a modelagem numérica e a otimização.')]}
